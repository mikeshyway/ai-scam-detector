# %% [markdown]
# # Transcript EDA and Model Training
#
# This notebook uses the scam/non-scam call conversation dataset for binary transcript classification. The YouTube scam transcript dataset should be used for educational demos only because it contains scam examples without a matching non-scam class.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.text_preprocessor import load_labeled_text_csv
df = load_labeled_text_csv(ROOT / 'data/raw/transcripts/scam_nonscam_calls.csv')
df.head()

# %%
df['label'].value_counts().rename(index={0: 'non-scam', 1: 'scam'})

# %%
from src.text_classifier import train_text_models
vectorizer, models, metrics = train_text_models(df['text'], df['label'], include_decision_tree=False)
{name: {'accuracy': m['accuracy'], 'f1': m['f1']} for name, m in metrics.items()}
