# %% [markdown]
# # Email EDA and Model Training
#
# This notebook documents the email phishing workflow for the capstone project using the SpamAssassin spam/ham folders.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.text_preprocessor import load_spamassassin_dataset
df = load_spamassassin_dataset(ROOT / 'data/raw/spamassassin')
df.head()

# %%
df['label'].value_counts().rename(index={0: 'ham', 1: 'spam'})

# %%
from src.text_classifier import train_text_models
vectorizer, models, metrics = train_text_models(df['text'], df['label'])
{name: {'accuracy': m['accuracy'], 'f1': m['f1']} for name, m in metrics.items()}
