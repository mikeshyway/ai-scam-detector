# %% [markdown]
# # Audio EDA and SVM Model
#
# This notebook documents the ASVspoof subset workflow. Audio files are converted into MFCC mean and standard deviation features, then an SVM classifier is trained on the saved arrays.

# %%
from pathlib import Path
import numpy as np
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
X = np.load(ROOT / 'data/processed/audio_X.npy')
y = np.load(ROOT / 'data/processed/audio_y.npy')
X.shape, np.bincount(y)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 3))
plt.plot(X[0])
plt.title('MFCC feature vector for one sample')
plt.xlabel('Feature index')
plt.ylabel('Value')
plt.show()

# %%
import sys
sys.path.insert(0, str(ROOT))
from src.audio_classifier import train_audio_svm
model, metrics = train_audio_svm(X, y)
{'accuracy': metrics['accuracy'], 'f1': metrics['f1']}
